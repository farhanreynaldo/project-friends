# %%
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen

# %%
special_case = ["The One With Phoebe's Dad",
 'The One Where Ross Finds Out',
 'The One Where Ross and Rachel...You Know',
 "The One With Barry and Mindy's Wedding",
 'The One Where Joey Moves Out',
 "The One With Phoebe's Husband",
 'The One With the Two Bullies',
 'The One Where Eddie Moves In',
 "The One Where Eddie Won't Go",
 'The One With the Chicken Pox',
 'The One With the Two Parties',
 'Friends - 915 - The One With The Mugging',
 'The One Where Old Yeller Dies',
 'The One With the Prom Video',
 'The One Where Dr. Remore Dies',
 'The One After the Superbowl',
 'The One With the Baby on the Bus']

# %%
def CharLine(soup):
    title = soup.title.get_text(strip=True)
    for p in soup.find_all('p'):
        if ':' in p.get_text():
            temp = p.get_text().split(':')
            char = temp[0].strip()
            line =temp[1]

            chars.append(char)
            lines.append(line)
            titles.append(title)

# %%
# %%time

url = 'https://fangj.github.io/friends/'
html_page = urlopen(url)
soup = BeautifulSoup(html_page, 'html.parser')

chars = []
lines = []
titles = []

for link in soup.find_all('a', href=True):
    episode_url = url + link.get('href')
    eps = BeautifulSoup(urlopen(episode_url).read().decode('utf-8', 'ignore'), 'html.parser')
    CharLine(eps)
# Out:
# Wall time: 3min 21s

# %%
#my_dict2 = {y:x for x,y in link_title.items()}
#my_dict2

# %%
links = []
for link in soup.find_all('a', href=True):
    links.append(link.get('href'))

# %%
d = {'title': titles, 'character': chars, 'line': lines}
df = pd.DataFrame(d)

# %%
df.title.value_counts()
# Out:
# Friends - 923-924 - The one in Barbados                                  623
# Friends - 10.17-10.18 - The Last One                                     610
# Untitled Document                                                        597
# The One With The Proposal                                                582
# The One That Could Have Been                                             572
# The One Where Rachel Has A Baby                                          557
# The One In Vegas                                                         552
# The One With Chandler and Monicas Wedding                               538
# The One With Ross's Wedding Parts I and II                               520
# The One After the Superbowl                                              458
# The One With The Truth About London                                      375
# 1001 - The One After Joey And Rachel Kiss                                357
# The One With Joey's Big Break                                            349
# Friends - 10.05 The One Where Rachel's Sister Baby-sits                  349
# The One With A Chick. And A Duck                                         346
# Friends - 10.11 - The One Where The Stripper Cries                       346
# Friends - 10.08 The One With The Late Thanksgiving                       339
# The One With Joeys New Brain                                            334
# Friends - 10.14 - The One With Princess Consuela                         333
# Friends - 10.12 - The One With Phoebe's Wedding                          328
# Friends - 10.13 - The One Where Joey Speaks French                       328
# The One With Joeys Fridge                                               326
# Friends - 920 - The one with the soap opera party                        326
# The One With The Ball                                                    324
# The One Where Rosita Dies                                                322
# Friends - 10.06 - The One With Ross' Grant                               321
# The One With Rachel's Date                                               317
# Friends - 922 - The one with the donor                                   317
# The One Where Monica Gets a New Roomate (The Pilot-The Uncut Version)    312
# The One Where Chandler Can't Remember Which Sister                       311
#                                                                         ...
# The One With the Lesbian Wedding                                         235
# The One With Ross's Inappropriate Song                                   233
# The One With The Jellyfish                                               232
# The One With Phoebe's Ex-Partner                                         232
# The One Where Phoebe Hates PBS                                           232
# The One With Ross' New Girlfriend                                        229
# The One With The Fake Monica                                             227
# The One With Phoebe's Husband                                            227
# The One With the Last                                                    226
# The One With Phoebes Uterus                                             225
# The One Where Ross Finds Out                                             222
# The One With The Butt                                                    220
# The One Where Theyre Up All Night                                       218
# The One With the Breast Milk                                             217
# The One With Barry and Mindy's Wedding                                   215
# 904 - The One With The Sharks                                            213
# The One With the Candy Hearts                                            206
# The One Where Mr. Heckles Dies                                           199
# The One With the Prom Video                                              198
# Friends: The Stuff Youve Never Seen                                     188
# 913 - The One Where Monica Sings                                          74
# The One With Two Parts, part 1                                            17
# The One With the Baby on the Bus                                           2
# The One Where Dr. Remore Dies                                              2
# The One Where Eddie Moves In                                               2
# The One With the Two Parties                                               2
# The One With the Two Bullies                                               2
# The One Where Old Yeller Dies                                              2
# The One Where Eddie Won't Go                                               2
# The One With the Chicken Pox                                               2
# Name: title, Length: 225, dtype: int64

# %%
df.to_csv('friends script test.csv')

# %% [markdown]
# ### MISC
# ***

# %%
url1 = 'https://fangj.github.io/friends/season/0911.html'
url2 = 'https://fangj.github.io/friends/season/0209.html'
response = get(url2)

# %%
#soup = BeautifulSoup(response.content, 'html.parser')
soup = BeautifulSoup(urlopen(url2).read(), 'html.parser')

# %%
def br_case1():
    for line in soup.find_all('p'):
        if ':' in line.get_text():
            temp = str(line.get_text).split('<br/>')
            for item in temp:
                print (item)
                print ('-------')
            
def br_case2():
    for line in soup.find_all('p'):
        if ':' in line.get_text():
            print(line.stripped_strings)
            
def br_casefinal(soup):
    for p in soup.find_all('p')[1:]:
        for line in p:
            #print(line)
            #print('---------')
            if ':' in line:
                temp = line.split(':')

                chars.append(temp[0].strip())
                lines.append(temp[1])

# %%
chars = []
lines = []
titles = []
br_casefinal(soup)
lines
# Out:
# [" Monica and Rachel's apartment. Monica, Rachel, Ross, and Phoebe\nare there. Phoebe is looking out the window.]",
#  ' Ooh, ooh, ooh, ooh, ooh. Ugly Naked Guy is decorating his tree. Oh my God, you\nshould see the size of his Christmas Balls.',
#  ' Hey.',
#  ' Hey.',
#  ' Hey.',
#  ' Hey, how much did you guys tip the super this year?',
#  " Yeah, we were gonna give fifty, but if you guys gave more, we don't wanna look\nbad.",
#  ' Oh, actually this year we just made him homemade cookies.',
#  ' And twenty-five it is.',
#  ' You gave him cookies?',
#  " Money is so impersonal. Cookies says someone really cares. . . Alright, we're\nbroke, but cookies do say that.",
#  ' I can see that. A plate of brownies once told me a limerick.',
#  ' Phoebs, let me ask you something, were, were these, uh, funny brownies?',
#  ' Not especially. But you know what, I think they had pot in them.',
#  ' So you guys, who else did you tip with cookies?',
#  ' Uhh, the mailman, the super.',
#  ' Oh, and the newspaper delivery guy.',
#  ' Oh my God.',
#  ' What?',
#  " Uhhh, I don't think you're gonna like this.",
#  ' Ooh, goooosh, ooh, these are cookies smashed in the sports section.',
#  ' Oh look, and he did my crossword puzzle.',
#  " Yeah, but not very well, unless 14-across, 'Gershwin musical' actually is\nbitemebitemebitemebiteme.",
#  ' ',
#  " I can't believe it's Christmas already. Ya know, I mean, one day your eatin' turkey,\nthe next thing ya know, your lords are a-leapin' and you geese are a-layin'.",
#  ' Which is why geese are so relaxed this time of year.',
#  ' Hey guys.',
#  ' Hey.',
#  " Hey Rach. I, uh, got you a little present. [Rachel is not impressed]. . I'll open\nit. It's a Slinky! Remember, huh. [sings] ",
#  ' Horrible and degrading list of reasons not to be with me?',
#  " How 'bout from now on we just call it the 'unfortunate incident'? [Rachel walks off]\nHey Gunther, you got stairs in your place?",
#  ' Yeah.',
#  ' Here, go nuts. [gives him the Slinky and goes and sits with others at the couches]',
#  ' Hey guys.',
#  ' Hey.',
#  " What's in the bag?",
#  ' Um, just some presents.',
#  " C'mon show us what you bought. . . You know you want to.",
#  ' [childishly] OK. OK, this is a picture frame from Ben to my parents, huh.',
#  ' Cute.',
#  ' I got some, uh, hers and hers towels for Susan and Carol. And, uh, I got this blouse\nfor mom.',
#  ' Ross, that is gorgeous!',
#  ' Yeah?',
#  " Look at these authentic fake medals. I tell ya, mom's gonna be voted best dressed\nat the make-believe military academy.",
#  ' Hey.',
#  ' Hey. Hi Phoebe.',
#  " Happy Christmas Eve Eve. [sees Ross's picture frame] Oh my God, where did you get\nthis?",
#  " Uh, Macy's, third floor, home furnishings.",
#  ' This is my father, this is a picture of my dad.',
#  " Nah, Phoebs, that's the guy that comes in the frame.",
#  " No it isn't, this is my dad, alright, I'll show you.",
#  ' Phoebe, I thought your dad was in prison.',
#  " No, that's my stepdad. My real dad's the one that ran out on us before I was born.",
#  ' How have you never been on Oprah?',
#  ' [showing her pictures] OK, look, see, this is him. My mother gave me this picture\nbefore she died, same guy.',
#  ' Honey, uh, this is a picture of the frame guy posing in front of a bright blue\nscreen with a collie.',
#  " It's not a blue screen... it's just, maybe it was just really clear that day. OK,\nI have to talk to my grandmother. [turns to leave]",
#  ' Oh, wait a minute honey.',
#  ' Phoebs. [Phoebe leaves]',
#  ' Wow.',
#  " So anyway, I'm trying to get my boss's ex-wife to sleep with me. . .",
#  ' Joey!',
#  " Oh, but when Phoebe has a problem, everyone's all ears!",
#  " Phoebe's grandmother's place. Phoebe's grandmother is sitting at the table,\nreading the obituaries, and crossing out names in the phonebook.]",
#  ' Esther Livingston. [scratches out name] Gone.',
#  ' Hi, Phoe.',
#  " Hi Gram. Whatcha doin'?",
#  ' Oh, just updating the phonebook.',
#  ' Um, gram, um, can I see the pictures of my dad again?',
#  ' [nervously] Oh. Oh, sure, sure, uh, uh, how come?',
#  ' Just, you know, to see... um.',
#  ' Oh, sure, yeah. [gets a box with the pictures] This is the one of you father\nin a meadow, and, uh, helping a little boy fly a kite, and here he is at a graduation. . .\nanother graduation. . . another graduation.',
#  ' OK, is this really my father?',
#  " Is it really your fa--I can't... well of course it is.",
#  " OK, I smell smoke. Maybe that's 'cause someone's pants are on fire.",
#  ' Look, I. . .',
#  ' Ya know, in all the years that we have been grandmother and granddaughter, you\nhave never lied to me.',
#  " Alright, that is not your father, that's just a picture of a guy in a frame.",
#  ' Oh God.',
#  " It was your mother's idea. Ya know, she didn't want you to know your real\nfather because it hurt her so much when he left, and, I didn't want to go along with it,\nbut, well then she died and, and it was harder to argue with her. Not impossible, but\nharder.",
#  " Alright, so, what, he's not a famous tree surgeon? And then, I guess, OK, he\ndoesn't live in a hut in Burma where there's no phones?",
#  ' Last I heard, he was a pharmacist somewhere upstate.',
#  ' OK, that makes no sense. Why would the villagers worship a pharmacist?',
#  ' Honey.',
#  ' [realizes] Oh.',
#  " Anyway, that's all I know. That, and this. [pulls apart a frame and pulls a\npicture out] This is the real him.",
#  ' Oh.',
#  " Monica and Rachel's apartment. Rachel, Chandler, and Joey are decorating the\nChristmas tree.]",
#  " Ya know I remember my father, all dressed up in the red suit, the big black\nboots, and the patent leather belt, sneakin around downstairs. He didn't want anybody to\nsee him but he'd be drunk so he'd stumble, crash into something and wake everybody up.",
#  " Well, that doesn't sound like a very merry Christmas.",
#  ' Who said anything about Christmas?',
#  ' Hi.',
#  ' Hey, anyone hear from Phoebe yet?',
#  " No, nothin'.",
#  " I hope she's OK.",
#  " Yeah, I know exactly what she's goin' through.",
#  " How do you know exactly what she's going through?",
#  ' She told us.',
#  ' So whaddya got there Monica?',
#  ' Just some stuff for the party.',
#  " Yeah, what're you guys doin' here, aren't you supposed to be Christmas shopping?",
#  " You guys haven't gotten your presents yet? Tomorrow's Christmas Eve, what're ya\ngonna do?",
#  " Don't you have to be Claymation to say stuff like that?",
#  " Oh, by the way Mon, I don't think the mailman liked your cookies. Here are the\nornaments your mom sent. [hands her a smashed box]",
#  " Well, maybe the mailman liked the cookies, we just didn't give him enough.",
#  ' Monica, pigeons learn faster that you.',
#  " Hey, Rach, you know what? I think, I think I know what'll make you feel better.\nHow 'bout you make a list about me.",
#  ' Wha... forget it Ross, no, I am not gonna stand here and make a list of. . .',
#  " C'mon Rachel.",
#  " OK, you're whiney, you are, you're obsessive, you are insecure, you're, you're\ngutless, you know, you don't ever, you don't just sort of seize the day, you know. You\nlike me for what, a year, you didn't do anything about it. And, uh, oh, you wear too much\nof that gel in your hair.",
#  ' See there, you uhh, alright, ya, you did what I said.',
#  " Yeah, and you know what? You're right, I do feel better, thank you Ross. [she\nwalks off and Ross puts his hand to his hair]",
#  " Back at Phoebe's. She is on the phone]",
#  " Yeah, um, in Albany, can I have the number of Frank Buffay. . . OK, um, in Ithica.\n. . alright, um, Saratoga. . . Oneonta. Alright, you know what, you shouldn't call youself\ninformation. [hangs up]",
#  ' Hey.',
#  ' Hello grandma, if that is in fact your real name.',
#  " C'mon now Phoe, don't still be mad at me. How's it going?",
#  " Well, not so good. Upstate's pretty big, he's pretty small, you do the math.",
#  " Well, I think you're better off without him. Oh honey, I know he's your daddy\nbut, but to me he's still the irresponsible creep who knocked up your mom and stole her\nGremlin.",
#  ' No I just, just wanted to know who he was, ya know.',
#  " I know. OK, I wasn't completely honest with you when I told you that, uh, I\ndidn't know exactly where he lived.",
#  ' Whattaya mean?',
#  " He lives at 74 Laurel Drive in Middletown. If you hit the Dairy Queen, you've\ngone too far. You can take my cab.",
#  ' Wow. Thank you.',
#  ' Now, remember, nobody else drives that cab.',
#  " Uh-huh, got it. Ooh, I'm gonna see my dad. Wish me luck, Grandpa! [blows a kiss to\na picture of Einstein]",
#  ' Chandler is standing on a street corner waiting for Phoebe in the cab. Joey\nwalks up.]',
#  ' Phoebe here with the cab yet?',
#  ' Yeah, she, she brought the invisible cab. . . hop in.',
#  ' Well she better get here soon, the outlet stores close at 7.',
#  " Hey, don't worry. I figure it'll be 2 hours to Phoebe's dad's house, they'll\nmeet, they'll chat, they'll swap life stories, we'll still have plenty of time.",
#  ' Hey, here she comes.',
#  ' Hey.',
#  ' Hey.',
#  ' Hey.',
#  ' Hey.',
#  " Can you believe this. In, like, two hours I'm gonna have a dad. Eeeshk.",
#  ' Eeeshk.',
#  ' Yeah, big stuff.',
#  " OK, let's go.",
#  ' OK.',
#  ' Alright, here, you have to hold this. [hands Chandler a piece of paper]',
#  ' OK. [reads paper] Brake left, gas right?',
#  " Uh-huh, yeah, that's my cheat sheet.",
#  " [grabs for seat belt] Where's my seat belt?",
#  " Oh, no no, that side doesn't have one, the paramedics had to cut through it.\n[Chandler jumps out of the car]",
#  ' [Chandler gets in the back seat] Hey!',
#  ' Hey. [Phoebe takes off, Joey and Chandler are thrown back in the seat]',
#  " Monica and Rachel's apartment. Monica is preparing for the party with Ross\nquestioning her.]",
#  " C'mon, just tell me, please, please.",
#  " For the sixteenth time, no... I do not think you're obsessive.",
#  " Oh, gosh, it's hot in here.",
#  ' Rach, get the heat. [Rachel holds up her hand with wet fingernail polish] Ross,\ncould you turn the heat down please?',
#  " Sure. By the way, there's a difference between being obsessive and. . .",
#  ' Ross, the heat!',
#  " Fine, OK! Heat, heat, heat, and I'm the obsessive one. [goes to the radiator and\nstarts turning the knob] OK, this way is on, so this is. . . [breaks off the knob] off.",
#  ' Did you just break the radiator?',
#  " No, no, I was turnin' the knob and, and. . . here it is.",
#  ' Well put it back.',
#  " It uhh, it won't go back.",
#  " I'll call the super.",
#  ' Here, let me try.',
#  " Oh, oh that's right, I forgot about your ability to fuse metal.",
#  " Hey, it's Funny's cousin, Not Funny.",
#  " [on phone] Hi, Mr. Treeger. Hi, it's Rachel Green from upstairs. Yes, ",
#  ' OK, tip the man.',
#  " No, if he doesn't like our cookies, too bad, I am not gonna be blackmailed. Look\nif worse comes to worse, it gets a little warm, we'll call it a theme party.",
#  " Hey, here's a theme",
#  " Outside Phoebe's dad's house. The cab pulls up.]",
#  ' Ooh, this is it, 74. [screeches to a halt, Joey and Chandler are thrown into the\nplexiglass wall in the cab]',
#  " Oh, so that's what this is for.",
#  " Wow, this is it, I'm gonna meet my dad. This is like the biggest thing ever, huh.",
#  ' Yeah.',
#  ' Sure is.',
#  " OK, here I go. I'm goin' in.",
#  ' Alright.',
#  ' Good luck Phoebs.',
#  " OK, here I go. . . here I go. . . I'm goin'. [she just sits in the cab]",
#  " Monica and Rachel's apartment. They are having their party. All the guests are\nstripped down because of the heat.]",
#  ' [answers door] Hi, welcome to our tropical Christmas party. You can put your coats\nand sweaters and pants and shirts in the bedroom.',
#  " [sitting at table talking to a girl] It's hard to tell because I'm sweating, but I\nuse exactly what the gel bottle says, an amount about the size of a pea. How, how can that\nbe too much?",
#  ' [carrying an ice cube tray] Ice, ice, ice squares anyone? Take a napkin. Alright.',
#  ' Monica, Monica, your guest are turning into jerky, OK.',
#  " Really? I'm perfectly comfortable. [one of the guest opens the refrigerator] Hey,\nhey, hey, get in line buddy, I was next. [she opens the refrigerator and leans into it]",
#  ' [answering the door] Mr. Treeger.',
#  ' Uhh, you said there was a party.',
#  ' Oh, yeah, well hey, welcome to our sauna.',
#  " Ahh, is it hot? My body always stays cool, probably 'cause I have so much\nskin. Hey, cheese!",
#  " Alright, alright, here's the chance. Monica give him cash, Rachel give him your\nearrings. Something, now, anything.",
#  ' No, I will not cave.',
#  " Yeah, I'm with Mon.",
#  " Alright, alright, you know how you say I never seize the day? Well, alright, even\nthough he's your super, I'm seizing. [approaches Mr. Treeger] Mr. Treeger, here is 50\nbucks, merry Christmas.",
#  " Oh wow, I didn't get you anything. Here's five back.",
#  " No no, no, that, that's your Christmas tip, alright. Oh, hey, do you think there's a\nchance you could fix that radiator now?",
#  " No can do, like I told the girl, I can't get a new knob until Thursday.",
#  ' Ross.',
#  ' Yeah.',
#  " [to Ross] Looks like he's playin' baseball.",
#  ' You mean hardball?',
#  ' Whatever.',
#  " What'cha gonna' do?",
#  " Excuse me, I'm seizing. Mr. Treeger, here's another 50, happy Hanukkah. Will uh,\nwill this help with the knob getting?",
#  " No, the place is not open 'till Tuesday. Am I not saying it right.",
#  ' So, wait, you really did like my cookies?',
#  ' Oh, yeah, they were so personal, really showed you cared.',
#  ' Nice seizing. . . gel boy.',
#  ' [to Rachel who is standing under mistletoe] So, uh, is this, uh, mistletoe?',
#  ' Huh-huh, no act--no, uhh, that, that is basil.',
#  ' Ahh, if it was mistletoe, I was gonna kiss ya.',
#  " Huh-hoo, yeah, no, it's still basil.",
#  " Outside Phoebe's dad's house. Phoebe is running back to the cab.]",
#  ' OK.',
#  " How far'd ya get?",
#  ' Mailbox.',
#  " Alright, we're gettin' closer.",
#  ' Uh-huh.',
#  " Phoebs, what's goin' on?",
#  " No, it's just like, ya know, it's a whole mess of stuff, ya know. It's like,\nyesterday, ya know, my dad was this, like, famous Burma tree surgeon guy and, ya know, now\nhe's a, a pharmacist guy and. . .",
#  " Well, maybe he's, maybe he's this really cool pharmacist guy.",
#  " Yeah, maybe, yeah. You know, and, and I'll knock on the door and, and he'll hug me\nand I'll have a dad. Ya know and I'll, I'll go to his pharmacy and everyone will be really\nnice to me 'cause, you know, I'm Franks daughter.",
#  ' Well, so why not go knock?',
#  " Well, 'cause, I mean, what if, what if he's not this great dad guy? I mean, what\nif, what if he's just still the dirtbag who ran out on my mom and us? You know what? I've\nalready lost a fake dad this week and I don't think I'm ready to lose a real one.",
#  " Phoebs, that's OK. You took a big step today.",
#  ' Yeah?',
#  " Yeah, and someday when you're ready, you'll make it past the hedges.",
#  " Yeah, and when you do, he'll be lucky to have you.",
#  " You guys. I'm sorry about your shopping.",
#  " Oh, that's OK, we'll figure something out.",
#  " Uh, listen Phoebs, I know you're not goin' in there but do you think it'd be alright\nif I went in and used his bathroom? Oh, that's fine, never mind. Cool, snow, kinda like a\nblank canvas.",
#  " Monica and Rachel's apartment. Ross, Monica, and Rachel are sitting around after\nthe party. Chandler, Joey, and Phoebe enter.]",
#  ' Ho, ho, ho, holy crap is it hot in here!',
#  ' Really, hey, you mind if I turn the heat down?',
#  " Hey, we could have used that kind of thinkin' earlier.",
#  " Hey, Phoebs, how'd it go.",
#  " Oh, I couldn't go in.",
#  " Honey, I'm sorry.",
#  ' Are you OK?',
#  " Yeah, yeah, no it's OK 'cause, I mean, I know he's there, so, that's enough for\nnow.",
#  " Hey, guys, it's after midnight, merry Christmas everyone. [Ross and Phoebe hug,\nMonica and Rachel hug, Chandler is left standing]",
#  " Hey, Monica, the knob was broken so I just turned it off from underneath, I hope\nthat's alright.",
#  " Monica and Rachel's apartment. Joey and Chandler are giving out their Christmas\npresents out of a cardboard box from a case of motor oil.]",
#  ' Rach, these are for you.',
#  " Wiper blades. I don't even have a car.",
#  " No, but with this new car smell, you'll think you do.",
#  ' OK, Phoebs, your turn.',
#  ' Ahh, toilet seat covers! Is that what you were doing while I was getting gas?',
#  ' Uh-huh.',
#  ' You guuuyys.',
#  ' And for Ross, Mr. Sweet-tooth.',
#  ' You got me a cola drink?',
#  ' And, a lemon lime.',
#  ' Well this, this is too much, I feel like I should get you another sweater.',
#  ' And last but not least.',
#  " They're ribbed for your pleasure.",
#  '//thecfsi.com/season2/210russ.htm"\nrectangle=" (70,2) (129, 84)  http']

# %%
#almost final
def CharLine(soup):
    title = soup.title.get_text(strip=True)
    for p in soup.find_all('p'):
        if ':' in p.get_text():
            temp = p.get_text().split(':')
            #char = temp[0].strip()
            #line =temp[1]
        
            chars.append(temp[0])
            lines.append(temp[1])
            titles.append(title)

# %%
lines = []
for p in soup.find_all('p'):
    #if p.find('b'):
    if ':' in p.get_text():
        temp = p.get_text().split(':')
        lines.append(temp[1])

# %%
def CharLine(soup):
    for b in soup.find_all("b"):
        char = b.get_text(strip=True).replace(':','')
        try:
            line = b.next_sibling.strip()
        except:
            continue
        print(line)
        #chars.append(char)
        #lines.append(line)
        #titles.append(title)

CharLine(soup)
# Out:
# : This is unbelievable. Its been like a half an hour. If this was a
# cartoon, youd be looking like a ham right about now.
# : Theres the waitress. Excuse me, Miss. Hello, Miss?
# : Its Phoebe! Hi!
# : Hi. Okay, will that be all?
# : Wait, wait! Wh-what are you doing here?
# : Yeah, um, I was over there, then you said, "Excuse me, hello
# Miss," so now Im here.
# : No, no... how come you are working here?
# : Right, yeah, cause its close to where I live, and the aprons are
# really cute.
# : Can we start over?
# : Yeah. Okay great. Im gonna be over here. (She wanders away.)
# : No, no, no!
# : I dont know whether hes testing me, or just acting out, but my
# monkey is out of control. But, he keeps erasing the messages on my machine,
# "supposedly" by accident.
# : No, yeah, Ive done that.
# : And then, like three days in a row he got to the newspaper before I did, and
# peed all over the crossword.
# : Ive never done that.
# : All right, now look at her and tell me she doesnt look exactly like
# her sister.
# : Im sayin I see a difference.
# : Theyre twins!
# : I dont care. Phoebes Phoebe. Ursulas... hot!
# : You know that thing, when you and I talk to each other about things?
# : Yeah.
# : Lets not do that any more.
# : Hey guys! Hey!
# : Hey Pheebs, guess who we saw today.
# : Ooh, ooh, fun! Okay... um, Liam Neeson.
# : Nope.
# : Morly Safer.
# : Nope.
# : The woman who cuts my hair!
# : Okay, look, this could be a really long game.
# : Your sister Ursula.
# : (Her face dropping) Oh, really.
# : Yeah, yeah, she works over at that place, uh...
# : Rifts. Yeah, I know.
# : Oh, you do? Because she said you guys havent talked in like years.
# : Hmmm? Yeah. So, um, is she fat?
# : Not from where
# was standin.
# : (Turning to Chandler) where were you standing?
# : Um, Pheebs, so, you guys just dont get along?
# : Its mostly just dumb sister stuff, you know, I mean, like, everyone
# always thought of her as the pretty one, you know... Oh, oh, she was the first one to
# start walking, even though I did it... later that same day. But, to my parents, by then it
# was like "yeah, right, well what else is new?"
# : Oh, Pheebs, Im sorry, Ive got to go. Ive got Lamaze class.
# : Oh, and Ive got Earth Science, but I'll catch you in Gym.
# : So, is this just gonna be you and Carol?
# : No, Susans gonna be there too. Weve got dads, weve got
# lesbians, the whole parenting team.
# : Well, isnt, isnt that gonna be weird?
# : No, no. (Distractedly putting on a jacket to go out) I mean, it mighta been
# at first, but by now I, I think Im pretty comfortable with the whole situation.
# : Ross, thats
# jacket.
# : I know.
# : Hi, were the Rostins. Err, Im J.C., and hes Michael, and
# were having a boy,
# a girl.
# : Good for you. Alrighty, next?
# : Hi, um, Im err, (has to clear his throat) Im Ross Geller, and err
# ah... (pats Carols bulge) ..thats, thats my boy in there, and uh,
# (points) this is Carol Willick, and this... is Susan Bunch. Susan is um Carols,
# just, com... (embarrassment finally overwhelms the poor fellow, who becomes incoherent
# until) ..whos next?
# : Im sorry, I didnt get... Susan is?
# : Susan is Carols, Carols, Carols, friend...
# : Life partner.
# : Like buddies.
# : Like lovers.
# : You know how close women can get.
# : Susan and I live together.
# : Although I was married to her.
# : Carol, not me.
# : Err, right.
# : Its a little complicated.
# : A little.
# : But were fine.
# : Absolutely. (Turns back to the woman next to him.) So, twins... hah!
# Thats like two births. (He struggles again.) Ouch.
# : And (he imitates the buzzer) to you too, Helen.
# : (Over the intercom) Nina Bookbinder is here to see you.
# : Oh, okay. Send her in.
# : Hi.
# : Hi, Nina. Come on in.
# : You wanted to see me?
# : Uh, Yes. Yes. Ive just been going over your data here, and little
# thing, youve been post-dating your Friday numbers.
# : Which is bad, because?
# : Well, it throws my WENUS out of whack.
# : Your... excuse me?
# : WENUS. (Coughs) Weekly Estimated Net...
# : Oh, Net Usage Statistics, right. Gotcha, gotcha. Wont happen again. I
# wouldnt want to do anything to hurt your... "wenus."
# : Its not just that shes cute, okay. Its just that...
# shes really really cute.
# : It doesnt matter. You dont dip your pen in the company ink.
# : Ross, your little creatures got the remote again.
# : Marcel, Marcel, give Rossie the remote. Marcel. Marcel, you give Rossie the
# remote right now... Marce... you give Rossie the remote...
# : Great.
# : Relax, Ill fix it.
# : (Looking at the television) Cool... "Urkel" in Spanish is
# "Urkel."
# : (looking at the remote) How did he do this?
# : (Looking out at the balcony) So tell me something, is leaving the
# Christmas lights up part of your plan to keep us merry all year long?
# : Ah no, you see,
# was supposed to take them down around New
# Years... but obviously
# forgot.
# : Well,
# was supposed to write "Rach, take down the
# lights" and put it on the re... frigerate... (finally noticing Monicas note
# stuck to the refrigerator) How long has that been there?
# : Hey, where you been?
# : I went back to Riffs. I think Ursula likes me. All I ordered was
# coffee, she brought me a tuna melt
# : Score.
# : She is so hot!
# : Yeah, listen. Okay, before you do anything Joey-like, you might wanna run
# it by err... (he indicates Phoebe, who is helping Ross understand the remote control.)
# : Pheebs?
# : (Jumping up) Yeah?
# : You think it would be okay if I asked out your sister?
# : Why? Why would you wanna... do that?  Why?
# : So that if we went out on a date, shed be there.
# : Well, I mean, Im not my sisters, you know, whatever, and um...
# I mean, its true, we were one egg, once, but err, you know, weve grown apart,
# so, um... I dont know, why not? Okay.
# : Cool, thanks.
# : You okay?
# : Yeah Im fine.
# : You wanna watch Laverne y Shirley?
# : Sorry.
# : Hi. Sorry Im late. Wheres, wheres Carol?
# : Stuck at school. Some parent-teacher thing. You can go. Ill get the
# information.
# : No... No... No. I think I should stay, I think we should both know
# whats going on.
# : Oh, good. Thisll be fun.
# : Alrighty. Were gonna start with some basic third stage breathing
# exercises, so Mummies, why dont you get on your back? And... coaches, you should be
# supporting Mummys head.
# : What? What? What?
# : I am supposed to be the mommy?
# : Okay, Im gonna play my sperm card
# more time.
# : Look, I dont see why I should have to miss out on the coaching
# training just because Im a woman.
# : I see. So what do you propose to do?
# : I will flip you for it.
# : Flip me for it? No, no, no... heads, heads, heads!
# : (Triumphantly) On your back... Mom.
# : Alright, Mommies, take a nice deep cleansing breath.
# : Good. Now imagine your vagina is opening like a flower.
# : Mr. D, hows it going, sir?
# : Ohh, its been better. The Annual Net Usage Statistics are in.
# : And?
# : Its pretty ugly. We havent seen an ANUS this bad since the
# seventies.
# : So what does this mean?
# : Well, were gonna be layin off people in every department.
# : Hey, listen, I know I came in late last week, but I slept funny, and my
# hair was very very &ndash;
# : Not you. Relax. Ever have to fire anyone?
# : Nina? Nina. (He goes around his desk to where she is sitting.) Nina. (In
# pain) Nina.
# : Are you okay?
# : (Looking down at her hand) Yes, yes I am. Err, listen, the reason that I
# called you in here today was, err... please dont hate me.
# : (Taking her hand away) What?
# : (Suddenly bright) Would you like to have dinner sometime?
# : So Pheebs, what do you want for your birthday?
# : Well, what I really want is for my mom to be alive and enjoy it with me.
# : Okay... Let me put it this way. Anything from
# : Ooh! Bath salts would be nice.
# : Ooh, okay... good.
# : What is this place?
# : Look, youre cold, I have to pee, and... (indicating the sign)
# ..theres a cup of coffee on the window. How bad could it be?
# : I think we have an answer.
# : Whats she doing here?
# : This could be Gods way of telling us to eat at home.
# : Think she got fired at Riffs?
# : No, no, no. We were there last night. She kept... (shuddering at the memory)
# ..bringing swordfish. (Indicating the ladies bathroom) are you gonna go to the, um?
# : Im gonna wait till after we order. Its her, right.
# : It looks like her.
# : Um, excuse me.
# : Yeah?
# : Hi, its us.
# : (Smiling blankly) Right, and its me.
# : So, so youre here too?
# : Much as you are.
# : (Without moving her lips) Your turn.
# : Err... we know what we want.
# : (Philosophically) Oh, thats good.
# : All we want is two Caffe Lattes.
# : And some biscottie cookies.
# : Good choice.
# : Definitely her.
# : Yeah.
# : I cant believe you. You still havent told that girl she
# doesnt have a job yet?
# : Well, you still havent taken down the Christmas lights.
# : Congratulations, I think youve found the worlds thinnest
# argument.
# : Im just trying to find the right moment, you know?
# : Oh, well, that shouldnt be so hard, now that youre dating.
# (Imitating men at their worst) "Sweetheart, youre fired, but how bout a
# quickie before I go to work?"
# : Hey.
# : Hey.
# : You know, once youre inside, you dont have to knock any more.
# : Ill get it.
# : Oh. Hi, Mr.Heckles.
# : Youre doing it again.
# : Were not doing anything. Were just sitting around talking,
# quietly.
# : I can hear you through the ceiling. My cats cant sleep.
# : You dont even have cats.
# : I could have cats.
# : (Closing the door) Goodbye Mr.Heckles.
# : Well try to keep it down.
# : Phoebe, could you do me a favour? Could you try this on? I just wanna make
# sure it fits.
# : Ooh, my first birthday present... (delightedly examining the cardigan in
# her lap) ..oh, this is really...
# : Oh, no no no. Its for Ursula. I just figured, you know, size-wise.
# : Ohhh... Sure, yeah... (disgustedly dropping the cardigan back into the bag)
# ..okay, it fits.
# : Are you seein her again tonight?
# : Yep. Ice Capades.
# : Wow, this is serious. Ive never known you to pay money for any kind
# of capade.
# : I dont know. I like her, you know. Shes different. Theres
# uh, somethin about her.
# : That you like, (snappily confronting Joey over the heads of the knitting
# circle) we get it. You like her. Great!
# : Hey, Phoebe, I asked you, and you said it was okay.
# : Alright, well, maybe now its not okay.
# : Okay... Well maybe now Im not okay with it not being okay.
# : Okay.
# : Knit, good woman, knit, knit!
# : And thats the Chrysler Building right there.
# : Nina.
# : Mr.Douglas... (flirting defensively) ..cool tie.
# : (Shutting the door, then pointing vaguely at Ninas shapely
# departure) Shes still here.
# : Yes, yes she is. Didnt I memo you on this? See, after I let her go,
# err, I got a call from her psychiatrist, Dr. Flanen-nen, Dr. Flanen, Dr. Flan.
# : And err, he informed me that uh, she took the news rather badly, in fact,
# he uh, mentioned the word frenzy.
# : Youre kidding? She seems so...
# : Oh, no, no. Nina... (miming fairies twinkling around his head) ..she is
# whooo wewee-woo whoo whoo! In fact, if you asked her right now, she would have no
# recollection of being fired at all, none at all.
# : Thats unbelievable.
# : And yet, believable. So I decided not to fire her again until I can be
# assured that she will be no threat to herself, or others.
# : I see. I guess you never really know whats goin on inside
# a persons head.
# : Well, I guess thats why they call it psychology, sir.
# : ..a sound Mom and Dad never forget. For this after all, is the
# miracle of birth.
# : Lights please? And thats having a baby. Next week is our final
# class.
# : Susan, go deep.
# : This is impossible. Its just impossible.
# : What is, honey?
# : What that woman... did. I am
# doin that. Its just
# gonna have to stay in, thats all, everything will be the same, itll just stay
# .
# : Carol, honey, shhh, shhh, everythings gonna be alright.
# : (screaming at Ross) Oh, what do you know?  No one's going up to you and
# saying, "Hi, is that your nostril?  Mind if we push this
# : Carol, Carol, sweetie. Cleansing breath.
# : I know its frightening, but, big picture. The birth part is just one
# day, and when its over, were all gonna be parents for the rest of our lives.
# : I mean, thats what this is all about, right? Ross? Ross?
# : Im gonna be a father.
# : This is just occurring to you?
# : I always knew I was havin a baby, I just never realised the baby was
# having me.
# : (She comforts him too) Oh, youre gonna be great!
# : Aw, how can you say that? I cant even get Marcel to stop eating the
# bath mat. How am I gonna raise a kid?
# : You know, Ross, some scientists are now saying that, that monkeys and
# babies are actually different.
# : Wherere you going?
# : Out.
# : With?
# : (Spreading his arms wide) Yes.
# : Alright, could I just ask you one question?
# : Have you two, you know... like... you know... you know... yet?
# : Well, not that its any of your business, but, no, we havent,
# okay?
# : You meant sex, right?
# : Do you have a sec?
# : Ah, sure, Nina. Whats up?
# : I dont know. For the past couple days, people have been
# me and giving me these really strange looks.
# : Oh, well, ah... maybe thats because theyre ah... jealous, of
# us.
# : Maybe. But that doesnt explain why they keep taking my scissors.
# : Ah, well, maybe thats, ah, because youre getting a big raise.
# : I am?
# : Sure, why not?
# : Oh my god! (Rushing over to give him a big hug) Youre amazing!
# : Oh, you dont know. (Presses a button.) Helen, could you make sure
# we put through the paperwork on Miss Bookbinders raise?
# : (Over the intercom) So you still want me to send her psychological profile
# to Personnel?
# : What?
# : Helen drinks. (Insincerely) Will you marry me?
# : Well, I ended up telling her everything.
# : Oh, howd she take it?
# : Pretty well. Except for the stapler thing. (He holds up a bandaged hand.)
# Little tip: if youre ever in a similar situation, never
# leave your
# hand... (he mimes Nina taking her revenge) ..on the desk.
# : Okay, I think I get how to do this.
# : Alright, so, can we turn this off? Can we just make it... make them go
# away? Because I cant, I cant watch.
# : (Remotely turning off the television) okay, Pheebs, theyre gone.
# : Okay.
# : Are you alright?
# : Yeah. Its just, you know, its this whole stupid
# thing, its...
# : Okay, Pheebs, can I ask? So, hes going out with her. I mean, is it
# really so terrible?
# : Um, yeah. Look, I mean, Im not saying shes like
# or
# anything. She just, you know, shes always breaking my
# . When I was
# eight, and I wouldnt let her have my Judy Jetson thermos, so she threw it under the
# bus. And then, oh, and then there was Randy Brown, who was like... Have you ever had a
# boyfriend who was like your best friend?
# : (Wistfully, shaking their heads) No.
# : Well, but thats what he was for me. And she you know, kind of stole
# him away, and then... broke his heart... and then he wouldnt even
# to me
# any more. Because he said he didnt wanna be around...
# that looked
# like either one of us.
# : Oh... Oh, Pheebs.
# : I mean, I know Joey is not my boyfriend, or my thermos, or anything, but...
# : Youre not gonna lose him.
# : Hon, you gotta talk to Joey.
# : Yeah. Okay.
# : No, come on, he doesnt know this stuff. If he knew how you felt.
# : But hes falling in
# with her.
# : Oh please, theyve been going out a week. They havent even slept
# together yet, I mean, thats not serious.
# : Okay... Okay.
# : Oh, okay, oh.
# : (Surprised) Oh.
# : Yeah, um, may we help you?
# : Rachel, what are you doing? Its freezing out here. Would you come
# back inside?
# : No no no no no. You wanted me to take them down, so... (she climbs onto the
# railing to reach the top of a pole) ..Im takin em down. Okay? Whoa!
# (Screams.)
# : Oh-my-god Rachel! (Rushing out to look over the edge) Rachel!
# : (To Monica) Im okay! Im okay! (She knocks on Mr. Heckles's
# window.) Mr. Heckles, Mr. Heckles could you help me please?
# : See, this is just the kind of thing I was talking about.

# %%
#Old Script
def char_line():
    char = []
    line = []
    for item in lines:
        if ':' in item.text:
            temp = item.text.split(':')
            char.append(temp[0])
            clean_line = temp[1].replace('\n', ' ').replace('\xa0', '').strip()
            line.append(clean_line)
            
#second old script
def CharLine(soup):
    if not soup.find("b"):
        for strong in soup.find_all("strong"):
            title = soup.title.get_text(strip=True)
            char = strong.get_text(strip=True).replace(':','')
            try:
                line = strong.next_sibling.replace('\n', ' ').replace('\xa0', '').replace(':','').strip()
            except:
                continue
                
            chars.append(char)
            lines.append(line)
            titles.append(title)
    else:
        for b in soup.find_all("b"):
            title = soup.title.get_text(strip=True)
            char = b.get_text(strip=True).replace(':','')
            try:
                line = b.next_sibling.replace('\n', ' ').replace('\xa0', '').strip()
            except:
                continue
                    
            chars.append(char)
            lines.append(line)
            titles.append(title)
            
#third old script
def CharLine(soup):
    for item in soup.find_all(['b', 'strong']):
        title = soup.title.get_text(strip=True)
        char = item.get_text(strip=True).replace(':','')
        try:
            line = item.next_sibling.replace(':','').replace('\n', ' ').strip()
        except:
            continue
        linked = link.get('href')
        
        chars.append(char)
        lines.append(line)
        titles.append(title)
        link_title[title] = linked
        
#fourth old script
def CharLine(soup):
    for item in soup.find_all(['b', 'strong']):
        title = soup.title.get_text(strip=True)
        char = item.get_text(strip=True).replace(':','')
        try:
            line = item.next_sibling.replace(':','').replace('\n', ' ').strip()
        except:
            continue
        linked = link.get('href')
        
        chars.append(char)
        lines.append(line)
        titles.append(title)
        link_title[title] = linked

# %%
'''for string in soup.stripped_strings:
    print(repr(string))'''
